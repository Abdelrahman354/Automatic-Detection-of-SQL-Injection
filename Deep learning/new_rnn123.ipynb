# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import StratifiedKFold
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout, Bidirectional
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import confusion_matrix, classification_report
import os

# Configure TensorFlow to use GPU
os.environ['CUDA_VISIBLE_DEVICES'] = '0'
# Load CSV file
df = pd.read_csv(r"C:\Users\abdel\Downloads\data set\SQLiV3.csv")

# %%
print(df.columns)
for i in range(0, 30953):
    if pd.isnull(df.iloc[i, 0]):
        df.iloc[i, 0] = df.iloc[i, 1]
    elif pd.isnull(df.iloc[i, 1]):
        df.iloc[i, 1] = df.iloc[i, 2]

print(df.isna().sum())
print(df.head())

# Data Cleaning
df['Label'] = df['Label'].astype(str)
df = df[~df['Label'].str.contains('[a-zA-Z]')]
df['Label'] = pd.to_numeric(df['Label'], errors='coerce', downcast='integer')
df['Label'] = df['Label'].astype('float32')
df = df.dropna(subset=['Sentence', 'Label'])

# Tokenization and Padding
max_words = 10000
max_sequence_length = 100
tokenizer = Tokenizer(num_words=max_words, oov_token="<OOV>")
tokenizer.fit_on_texts(df['Sentence'])
sequences = tokenizer.texts_to_sequences(df['Sentence'])
padded_sequences = pad_sequences(sequences, maxlen=max_sequence_length, padding='post', truncating='post')

# RNN Model
embedding_dim = 50  # Increased embedding dimension
model = Sequential([
    Embedding(input_dim=max_words, output_dim=embedding_dim, input_length=max_sequence_length),
    Bidirectional(LSTM(256, return_sequences=True)),  # Increased LSTM units
    Dropout(0.3),
    Bidirectional(LSTM(256)),
    Dense(128, activation='relu'),  
    Dropout(0.3),
    Dense(1, activation='sigmoid')
])
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# K-fold Cross-Validation
k_folds =10  # Choose the number of folds
skf = StratifiedKFold(n_splits=k_folds, shuffle=True, random_state=42)

# Initialize variables to store metrics
all_tp, all_fp, all_tn, all_fn = 0, 0, 0, 0
overall_accuracy = 0.0  # Initialize overall accuracy variable

for fold, (train_index, test_index) in enumerate(skf.split(padded_sequences, df['Label'])):
    print(f"\nTraining Fold {fold + 1}")
    
    train_padded = padded_sequences[train_index]
    test_padded = padded_sequences[test_index]
    
    labels_train = df['Label'].iloc[train_index]
    labels_test = df['Label'].iloc[test_index]

    # Early stopping
    early_stopping = EarlyStopping(monitor='val_loss', patience=2, restore_best_weights=True)
    
    # Training
    model.fit(train_padded, labels_train, epochs=10, validation_data=(test_padded, labels_test), callbacks=[early_stopping])

    # Evaluate
    test_loss, test_accuracy = model.evaluate(test_padded, labels_test)
    overall_accuracy += test_accuracy  # Accumulate accuracy for each fold
    print(f'Test Accuracy (Fold {fold + 1}): {test_accuracy * 100:.2f}%')

    # Confusion Matrix and Metrics
    predictions = (model.predict(test_padded) > 0.5).astype("int32")
    cm = confusion_matrix(labels_test, predictions)

    tp, fp, fn, tn = cm.ravel()
    all_tp += tp
    all_fp += fp
    all_tn += tn
    all_fn += fn

# Calculate and print overall accuracy
overall_accuracy /= k_folds
print(f'\nOverall Accuracy Across all Folds: {overall_accuracy * 100:.2f}%')
# Out:
# Index(['Sentence', 'Label', 'Unnamed: 2', 'Unnamed: 3'], dtype='object')
# Sentence          1
# Label             0
# Unnamed: 2    30916
# Unnamed: 3    31209
# dtype: int64
#                                             Sentence Label Unnamed: 2  \
# 0                  " or pg_sleep  (  __TIME__  )  --     1        NaN
# 1  create user name identified by pass123 tempora...     1          1
# 2   AND 1  =  utl_inaddr.get_host_address   (    ...     1        NaN
# 3   select * from users where id  =  '1' or @ @1 ...     1        NaN
# 4   select * from users where id  =  1 or 1#"  ( ...     1        NaN
#
#    Unnamed: 3
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#
# Training Fold 1
# Epoch 1/10
# 877/877 [==============================] - 60s 60ms/step - loss: 0.0522 - accuracy: 0.9842 - val_loss: 0.0226 - val_accuracy: 0.9942
# Epoch 2/10
# 877/877 [==============================] - 51s 58ms/step - loss: 0.0173 - accuracy: 0.9960 - val_loss: 0.0257 - val_accuracy: 0.9913
# Epoch 3/10
# 877/877 [==============================] - 51s 58ms/step - loss: 0.0471 - accuracy: 0.9900 - val_loss: 0.0451 - val_accuracy: 0.9913
# 98/98 [==============================] - 2s 24ms/step - loss: 0.0226 - accuracy: 0.9942
# Test Accuracy (Fold 1): 99.42%
# 98/98 [==============================] - 3s 23ms/step
#
# Training Fold 2
# Epoch 1/10
# 877/877 [==============================] - 51s 58ms/step - loss: 0.0189 - accuracy: 0.9955 - val_loss: 0.0086 - val_accuracy: 0.9971
# Epoch 2/10
# 877/877 [==============================] - 51s 58ms/step - loss: 0.0113 - accuracy: 0.9972 - val_loss: 0.0070 - val_accuracy: 0.9981
# Epoch 3/10
# 877/877 [==============================] - 51s 58ms/step - loss: 0.0090 - accuracy: 0.9981 - val_loss: 0.0057 - val_accuracy: 0.9981
# Epoch 4/10
# 877/877 [==============================] - 51s 58ms/step - loss: 0.0069 - accuracy: 0.9987 - val_loss: 0.0098 - val_accuracy: 0.9978
# Epoch 5/10
# 877/877 [==============================] - 51s 58ms/step - loss: 0.0073 - accuracy: 0.9986 - val_loss: 0.0115 - val_accuracy: 0.9942
# 98/98 [==============================] - 2s 24ms/step - loss: 0.0057 - accuracy: 0.9981
# Test Accuracy (Fold 2): 99.81%
# 98/98 [==============================] - 2s 23ms/step
#
# Training Fold 3
# Epoch 1/10
# 877/877 [==============================] - 50s 57ms/step - loss: 0.0097 - accuracy: 0.9979 - val_loss: 0.0100 - val_accuracy: 0.9984
# Epoch 2/10
# 877/877 [==============================] - 48s 55ms/step - loss: 0.0078 - accuracy: 0.9984 - val_loss: 0.0143 - val_accuracy: 0.9968
# Epoch 3/10
# 877/877 [==============================] - 49s 56ms/step - loss: 0.0064 - accuracy: 0.9988 - val_loss: 0.0128 - val_accuracy: 0.9971
# 98/98 [==============================] - 2s 23ms/step - loss: 0.0100 - accuracy: 0.9984
# Test Accuracy (Fold 3): 99.84%
# 98/98 [==============================] - 2s 22ms/step
#
# Training Fold 4
# Epoch 1/10
# 877/877 [==============================] - 48s 55ms/step - loss: 0.0093 - accuracy: 0.9983 - val_loss: 0.0048 - val_accuracy: 0.9990
# Epoch 2/10
# 877/877 [==============================] - 49s 56ms/step - loss: 0.0071 - accuracy: 0.9987 - val_loss: 0.0077 - val_accuracy: 0.9987
# Epoch 3/10
# 877/877 [==============================] - 49s 56ms/step - loss: 0.0077 - accuracy: 0.9985 - val_loss: 0.0056 - val_accuracy: 0.9984
# 98/98 [==============================] - 2s 24ms/step - loss: 0.0048 - accuracy: 0.9990
# Test Accuracy (Fold 4): 99.90%
# 98/98 [==============================] - 2s 24ms/step
#
# Training Fold 5
# Epoch 1/10
# 877/877 [==============================] - 50s 57ms/step - loss: 0.0065 - accuracy: 0.9988 - val_loss: 0.0072 - val_accuracy: 0.9990
# Epoch 2/10
# 877/877 [==============================] - 51s 58ms/step - loss: 0.0065 - accuracy: 0.9987 - val_loss: 0.0059 - val_accuracy: 0.9990
# Epoch 3/10
# 877/877 [==============================] - 51s 58ms/step - loss: 0.0056 - accuracy: 0.9990 - val_loss: 0.0066 - val_accuracy: 0.9987
# Epoch 4/10
# 877/877 [==============================] - 50s 57ms/step - loss: 0.0054 - accuracy: 0.9991 - val_loss: 0.0061 - val_accuracy: 0.9990
# 98/98 [==============================] - 2s 24ms/step - loss: 0.0059 - accuracy: 0.9990
# Test Accuracy (Fold 5): 99.90%
# 98/98 [==============================] - 2s 23ms/step
#
# Training Fold 6
# Epoch 1/10
# 877/877 [==============================] - 50s 57ms/step - loss: 0.0065 - accuracy: 0.9989 - val_loss: 0.0041 - val_accuracy: 0.9994
# Epoch 2/10
# 877/877 [==============================] - 50s 57ms/step - loss: 0.0066 - accuracy: 0.9988 - val_loss: 0.0091 - val_accuracy: 0.9984
# Epoch 3/10
# 877/877 [==============================] - 50s 58ms/step - loss: 0.0071 - accuracy: 0.9986 - val_loss: 0.0049 - val_accuracy: 0.9990
# 98/98 [==============================] - 2s 24ms/step - loss: 0.0041 - accuracy: 0.9994
# Test Accuracy (Fold 6): 99.94%
# 98/98 [==============================] - 2s 23ms/step
#
# Training Fold 7
# Epoch 1/10
# 877/877 [==============================] - 50s 57ms/step - loss: 0.0052 - accuracy: 0.9991 - val_loss: 0.0069 - val_accuracy: 0.9990
# Epoch 2/10
# 877/877 [==============================] - 51s 58ms/step - loss: 0.0061 - accuracy: 0.9990 - val_loss: 0.0078 - val_accuracy: 0.9984
# Epoch 3/10
# 877/877 [==============================] - 50s 57ms/step - loss: 0.0080 - accuracy: 0.9984 - val_loss: 0.0071 - val_accuracy: 0.9987
# 98/98 [==============================] - 2s 24ms/step - loss: 0.0069 - accuracy: 0.9990
# Test Accuracy (Fold 7): 99.90%
# 98/98 [==============================] - 3s 26ms/step
#
# Training Fold 8
# Epoch 1/10
# 877/877 [==============================] - 52s 59ms/step - loss: 0.0053 - accuracy: 0.9991 - val_loss: 0.0035 - val_accuracy: 0.9997
# Epoch 2/10
# 877/877 [==============================] - 52s 59ms/step - loss: 0.0055 - accuracy: 0.9991 - val_loss: 0.0033 - val_accuracy: 0.9994
# Epoch 3/10
# 877/877 [==============================] - 53s 60ms/step - loss: 0.0053 - accuracy: 0.9991 - val_loss: 0.0055 - val_accuracy: 0.9987
# Epoch 4/10
# 877/877 [==============================] - 53s 60ms/step - loss: 0.0081 - accuracy: 0.9984 - val_loss: 0.0031 - val_accuracy: 0.9997
# Epoch 5/10
# 877/877 [==============================] - 52s 59ms/step - loss: 0.0064 - accuracy: 0.9989 - val_loss: 0.0078 - val_accuracy: 0.9994
# Epoch 6/10
# 877/877 [==============================] - 53s 60ms/step - loss: 0.0068 - accuracy: 0.9988 - val_loss: 0.0055 - val_accuracy: 0.9994
# 98/98 [==============================] - 2s 25ms/step - loss: 0.0031 - accuracy: 0.9997
# Test Accuracy (Fold 8): 99.97%
# 98/98 [==============================] - 2s 23ms/step
#
# Training Fold 9
# Epoch 1/10
# 877/877 [==============================] - 53s 60ms/step - loss: 0.0057 - accuracy: 0.9990 - val_loss: 0.0086 - val_accuracy: 0.9987
# Epoch 2/10
# 877/877 [==============================] - 53s 61ms/step - loss: 0.0048 - accuracy: 0.9992 - val_loss: 0.0058 - val_accuracy: 0.9990
# Epoch 3/10
# 877/877 [==============================] - 52s 59ms/step - loss: 0.0046 - accuracy: 0.9993 - val_loss: 0.0060 - val_accuracy: 0.9990
# Epoch 4/10
# 877/877 [==============================] - 52s 59ms/step - loss: 0.0048 - accuracy: 0.9991 - val_loss: 0.0066 - val_accuracy: 0.9990
# 98/98 [==============================] - 2s 24ms/step - loss: 0.0058 - accuracy: 0.9990
# Test Accuracy (Fold 9): 99.90%
# 98/98 [==============================] - 2s 22ms/step
#
# Training Fold 10
# Epoch 1/10
# 877/877 [==============================] - 51s 59ms/step - loss: 0.0047 - accuracy: 0.9992 - val_loss: 0.0063 - val_accuracy: 0.9990
# Epoch 2/10
# 877/877 [==============================] - 52s 60ms/step - loss: 0.0064 - accuracy: 0.9989 - val_loss: 0.0072 - val_accuracy: 0.9981
# Epoch 3/10
# 877/877 [==============================] - 51s 58ms/step - loss: 0.0116 - accuracy: 0.9977 - val_loss: 0.0098 - val_accuracy: 0.9981
# 98/98 [==============================] - 2s 24ms/step - loss: 0.0063 - accuracy: 0.9990
# Test Accuracy (Fold 10): 99.90%
# 98/98 [==============================] - 2s 22ms/step
#
# Overall Accuracy Across all Folds: 99.85%

# %%
all_tp = int(all_tp)
all_fn = int(all_fn)
all_fp = int(all_fp)
all_tn = int(all_tn)

cm = pd.DataFrame(
    data=[[all_tp , all_fp ], [all_fn ,all_tn ]],
    index=['Actual 0', 'Actual 1'],
    columns=['Predicted 0', 'Predicted 1']
)


sns.heatmap(cm, annot=True,  fmt='5', cmap='Blues', center=True)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# Print average classification report
average_classification_report = classification_report(df['Label'], (model.predict(padded_sequences) > 0.5).astype(int))
print(f'\nAverage Classification Report:\n{average_classification_report}')
print(f'\nabdo:{cm}')
# Out:
# 974/974 [==============================] - 23s 23ms/step
#
# Average Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     19493
#          1.0       1.00      1.00      1.00     11673
#
#     accuracy                           1.00     31166
#    macro avg       1.00      1.00      1.00     31166
# weighted avg       1.00      1.00      1.00     31166
#
#
# abdo:          Predicted 0  Predicted 1
# Actual 0        19483           10
# Actual 1           37        11636

# %%
import matplotlib.pyplot as plt
# Pie chart 
label_counts = df['Label'].value_counts()

plt.pie(label_counts.values , labels=label_counts.index, autopct='%1.1f%%', colors=['lightcoral', 'lightblue'])
plt.show()

# %%
model.save(r"C:\Users\abdel\Downloads\grm\abdo.h5")
