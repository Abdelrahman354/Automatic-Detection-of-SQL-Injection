# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout, Bidirectional
# Train the model with early stopping
from tensorflow.keras.callbacks import EarlyStopping
# Load your CSV file
import os

# Configure TensorFlow to use GPU
os.environ['CUDA_VISIBLE_DEVICES'] = '0'

df = pd.read_csv(r"C:\Users\abdel\Downloads\data set\SQLiV3.csv")

# %%
print(df.columns)
for i in range(0, 20921):
    if pd.isnull(df.iloc[i, 0]):
        df.iloc[i, 0] = df.iloc[i, 1]
    elif pd.isnull(df.iloc[i, 1]):
        df.iloc[i, 1] = df.iloc[i, 2]
print(df.isna().sum())
print(df.head())

# Data Cleaning
df['Label'] = df['Label'].astype(str)
df = df[~df['Label'].str.contains('[a-zA-Z]')]
df['Label'] = pd.to_numeric(df['Label'], errors='coerce', downcast='integer')
df['Label'] = df['Label'].astype('float32')
df = df.dropna(subset=['Sentence', 'Label'])

# Split data
train_data, test_data = train_test_split(df, test_size=0.2, random_state=42)

# Tokenization and Padding
max_words = 10000
max_sequence_length = 100
tokenizer = Tokenizer(num_words=max_words, oov_token="<OOV>")
tokenizer.fit_on_texts(train_data['Sentence'])
train_sequences = tokenizer.texts_to_sequences(train_data['Sentence'])
test_sequences = tokenizer.texts_to_sequences(test_data['Sentence'])
train_padded = pad_sequences(train_sequences, maxlen=max_sequence_length, padding='post', truncating='post')
test_padded = pad_sequences(test_sequences, maxlen=max_sequence_length, padding='post', truncating='post')

#  RNN Model
embedding_dim = 50  # Increased embedding dimension
model = Sequential([
    Embedding(input_dim=max_words, output_dim=embedding_dim, input_length=max_sequence_length),
    Bidirectional(LSTM(256, return_sequences=True)),  # Increased LSTM units
    Dropout(0.5),
    Bidirectional(LSTM(256)),
    Dense(128, activation='relu'),  # Additional dense layer
    Dropout(0.5),
    Dense(1, activation='sigmoid')
])
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

# Training
labels_train = train_data['Label']
labels_test = test_data['Label']
model.fit(train_padded, labels_train, epochs=10, validation_data=(test_padded, labels_test), callbacks=[early_stopping])

# Evaluate
test_loss, test_accuracy = model.evaluate(test_padded, labels_test)
print(f'Test Accuracy: {test_accuracy * 100:.2f}%')
# Out:
# Index(['Sentence', 'Label', 'Unnamed: 2', 'Unnamed: 3'], dtype='object')
# Sentence          1
# Label             0
# Unnamed: 2    30916
# Unnamed: 3    31209
# dtype: int64
#                                             Sentence Label Unnamed: 2  \
# 0                  " or pg_sleep  (  __TIME__  )  --     1        NaN
# 1  create user name identified by pass123 tempora...     1          1
# 2   AND 1  =  utl_inaddr.get_host_address   (    ...     1        NaN
# 3   select * from users where id  =  '1' or @ @1 ...     1        NaN
# 4   select * from users where id  =  1 or 1#"  ( ...     1        NaN
#
#    Unnamed: 3
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 32
#      30 #  RNN Model
#      31 embedding_dim = 50  # Increased embedding dimension
# ---> 32 model = Sequential([
#      33     Embedding(input_dim=max_words, output_dim=embedding_dim, input_length=max_sequence_length),
#      34     Bidirectional(LSTM(256, return_sequences=True)),  # Increased LSTM units
#      35     Dropout(0.5),
#      36     Bidirectional(LSTM(256)),
#      37     Dense(128, activation='relu'),  # Additional dense layer
#      38     Dropout(0.5),
#      39     Dense(1, activation='sigmoid')
#      40 ])
#      41 model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
#      43 # Early stopping
#
# File c:\Users\abdel\anaconda3\lib\site-packages\tensorflow\python\trackable\base.py:205, in no_automatic_dependency_tracking.<locals>._method_wrapper(self, *args, **kwargs)
#     203 self._self_setattr_tracking = False  # pylint: disable=protected-access
#     204 try:
# --> 205   result = method(self, *args, **kwargs)
#     206 finally:
#     207   self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# File c:\Users\abdel\anaconda3\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\abdel\anaconda3\lib\site-packages\keras\engine\sequential.py:114, in Sequential.__init__(self, layers, name)
#     106 """Creates a `Sequential` model instance.
#     107
#     108 Args:
#     109   layers: Optional list of layers to add to the model.
#     110   name: Optional name for the model.
#     111 """
#     112 # Skip the init in FunctionalModel since model doesn't have input/output
#     113 # yet
# --> 114 super(functional.Functional, self).__init__(name=name, autocast=False)
#     115 base_layer.keras_api_gauge.get_cell("Sequential").set(True)
#     116 self.supports_masking = True
#
# File c:\Users\abdel\anaconda3\lib\site-packages\tensorflow\python\trackable\base.py:205, in no_automatic_dependency_tracking.<locals>._method_wrapper(self, *args, **kwargs)
#     203 self._self_setattr_tracking = False  # pylint: disable=protected-access
#     204 try:
# --> 205   result = method(self, *args, **kwargs)
#     206 finally:
#     207   self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# File c:\Users\abdel\anaconda3\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\abdel\anaconda3\lib\site-packages\keras\engine\training.py:319, in Model.__init__(self, *args, **kwargs)
#     315 self._checkpoint = tf.train.Checkpoint(root=weakref.ref(self))
#     317 self._steps_per_execution = None
# --> 319 self._init_batch_counters()
#     320 self._base_model_initialized = True
#     322 # `jit_compile` starts off with None as default and gets overwritten by
#     323 # the value specified in `Model.compile`, and this is effective for
#     324 # `fit`, `evaluate`, and `predict`.
#
# File c:\Users\abdel\anaconda3\lib\site-packages\tensorflow\python\trackable\base.py:205, in no_automatic_dependency_tracking.<locals>._method_wrapper(self, *args, **kwargs)
#     203 self._self_setattr_tracking = False  # pylint: disable=protected-access
#     204 try:
# --> 205   result = method(self, *args, **kwargs)
#     206 finally:
#     207   self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# File c:\Users\abdel\anaconda3\lib\site-packages\keras\engine\training.py:334, in Model._init_batch_counters(self)
#     329 @tf.__internal__.tracking.no_automatic_dependency_tracking
#     330 def _init_batch_counters(self):
#     331     # Untracked Variables, used to keep track of mini-batches seen in `fit`,
#     332     # `evaluate`, and `predict`.
#     333     agg = tf.VariableAggregation.ONLY_FIRST_REPLICA
# --> 334     self._train_counter = tf.Variable(0, dtype="int64", aggregation=agg)
#     335     self._test_counter = tf.Variable(0, dtype="int64", aggregation=agg)
#     336     self._predict_counter = tf.Variable(0, dtype="int64", aggregation=agg)
#
# File c:\Users\abdel\anaconda3\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\abdel\anaconda3\lib\site-packages\tensorflow\python\ops\variables.py:266, in VariableMetaclass.__call__(cls, *args, **kwargs)
#     264   return cls._variable_v1_call(*args, **kwargs)
#     265 elif cls is Variable:
# --> 266   return cls._variable_v2_call(*args, **kwargs)
#     267 else:
#     268   return super(VariableMetaclass, cls).__call__(*args, **kwargs)
#
# File c:\Users\abdel\anaconda3\lib\site-packages\tensorflow\python\ops\variables.py:247, in VariableMetaclass._variable_v2_call(cls, initial_value, trainable, validate_shape, caching_device, name, variable_def, dtype, import_scope, constraint, synchronization, aggregation, shape)
#     245 if aggregation is None:
#     246   aggregation = VariableAggregation.NONE
# --> 247 return previous_getter(
#     248     initial_value=initial_value,
#     249     trainable=trainable,
#     250     validate_shape=validate_shape,
#     251     caching_device=caching_device,
#     252     name=name,
#     253     variable_def=variable_def,
#     254     dtype=dtype,
#     255     import_scope=import_scope,
#     256     constraint=constraint,
#     257     synchronization=synchronization,
#     258     aggregation=aggregation,
#     259     shape=shape)
#
# File c:\Users\abdel\anaconda3\lib\site-packages\tensorflow\python\ops\variables.py:240, in VariableMetaclass._variable_v2_call.<locals>.<lambda>(**kws)
#     226 def _variable_v2_call(cls,
#     227                       initial_value=None,
#     228                       trainable=None,
#    (...)
#     237                       aggregation=VariableAggregation.NONE,
#     238                       shape=None):
#     239   """Call on Variable class. Useful to force the signature."""
# --> 240   previous_getter = lambda **kws: default_variable_creator_v2(None, **kws)
#     241   for _, getter in ops.get_default_graph()._variable_creator_stack:  # pylint: disable=protected-access
#     242     previous_getter = _make_getter(getter, previous_getter)
#
# File c:\Users\abdel\anaconda3\lib\site-packages\tensorflow\python\ops\variable_scope.py:2755, in default_variable_creator_v2(next_creator, **kwargs)
#    2752 aggregation = kwargs.get("aggregation", None)
#    2753 shape = kwargs.get("shape", None)
# -> 2755 return resource_variable_ops.ResourceVariable(
#    2756     initial_value=initial_value,
#    2757     trainable=trainable,
#    2758     validate_shape=validate_shape,
#    2759     caching_device=caching_device,
#    2760     name=name,
#    2761     dtype=dtype,
#    2762     constraint=constraint,
#    2763     variable_def=variable_def,
#    2764     import_scope=import_scope,
#    2765     distribute_strategy=distribute_strategy,
#    2766     synchronization=synchronization,
#    2767     aggregation=aggregation,
#    2768     shape=shape)
#
# File c:\Users\abdel\anaconda3\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\abdel\anaconda3\lib\site-packages\tensorflow\python\ops\variables.py:268, in VariableMetaclass.__call__(cls, *args, **kwargs)
#     266   return cls._variable_v2_call(*args, **kwargs)
#     267 else:
# --> 268   return super(VariableMetaclass, cls).__call__(*args, **kwargs)
#
# File c:\Users\abdel\anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:1659, in ResourceVariable.__init__(self, initial_value, trainable, collections, validate_shape, caching_device, name, dtype, variable_def, import_scope, constraint, distribute_strategy, synchronization, aggregation, shape)
#    1656   self._init_from_proto(variable_def, import_scope=import_scope,
#    1657                         validate_shape=validate_shape)
#    1658 else:
# -> 1659   self._init_from_args(
#    1660       initial_value=initial_value,
#    1661       trainable=trainable,
#    1662       collections=collections,
#    1663       caching_device=caching_device,
#    1664       name=name,
#    1665       dtype=dtype,
#    1666       constraint=constraint,
#    1667       synchronization=synchronization,
#    1668       aggregation=aggregation,
#    1669       shape=shape,
#    1670       distribute_strategy=distribute_strategy,
#    1671       validate_shape=validate_shape,
#    1672   )
#
# File c:\Users\abdel\anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:1817, in ResourceVariable._init_from_args(self, initial_value, trainable, collections, caching_device, name, dtype, constraint, synchronization, aggregation, distribute_strategy, shape, validate_shape)
#    1815     self._update_uid = initial_value.checkpoint_position.restore_uid
#    1816     initial_value = initial_value.wrapped_value
# -> 1817   initial_value = ops.convert_to_tensor(
#    1818       initial_value, name="initial_value", dtype=dtype)
#    1819 if shape is not None:
#    1820   if not initial_value.shape.is_compatible_with(shape):
#
# File c:\Users\abdel\anaconda3\lib\site-packages\tensorflow\python\profiler\trace.py:183, in trace_wrapper.<locals>.inner_wrapper.<locals>.wrapped(*args, **kwargs)
#     181   with Trace(trace_name, **trace_kwargs):
#     182     return func(*args, **kwargs)
# --> 183 return func(*args, **kwargs)
#
# File c:\Users\abdel\anaconda3\lib\site-packages\tensorflow\python\framework\ops.py:1638, in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1629       raise RuntimeError(
#    1630           _add_error_prefix(
#    1631               f"Conversion function {conversion_func!r} for type "
#    (...)
#    1634               f"actual = {ret.dtype.base_dtype.name}",
#    1635               name=name))
#    1637 if ret is None:
# -> 1638   ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1640 if ret is NotImplemented:
#    1641   continue
#
# File c:\Users\abdel\anaconda3\lib\site-packages\tensorflow\python\framework\tensor_conversion_registry.py:48, in _default_conversion_function(***failed resolving arguments***)
#      46 def _default_conversion_function(value, dtype, name, as_ref):
#      47   del as_ref  # Unused.
# ---> 48   return constant_op.constant(value, dtype, name=name)
#
# File c:\Users\abdel\anaconda3\lib\site-packages\tensorflow\python\framework\constant_op.py:267, in constant(value, dtype, shape, name)
#     170 @tf_export("constant", v1=[])
#     171 def constant(value, dtype=None, shape=None, name="Const"):
#     172   """Creates a constant tensor from a tensor-like object.
#     173
#     174   Note: All eager `tf.Tensor` values are immutable (in contrast to
#    (...)
#     265     ValueError: if called on a symbolic tensor.
#     266   """
# --> 267   return _constant_impl(value, dtype, shape, name, verify_shape=False,
#     268                         allow_broadcast=True)
#
# File c:\Users\abdel\anaconda3\lib\site-packages\tensorflow\python\framework\constant_op.py:279, in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     277     with trace.Trace("tf.constant"):
#     278       return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
# --> 279   return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     281 g = ops.get_default_graph()
#     282 tensor_value = attr_value_pb2.AttrValue()
#
# File c:\Users\abdel\anaconda3\lib\site-packages\tensorflow\python\framework\constant_op.py:304, in _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     302 def _constant_eager_impl(ctx, value, dtype, shape, verify_shape):
#     303   """Creates a constant on the current device."""
# --> 304   t = convert_to_eager_tensor(value, ctx, dtype)
#     305   if shape is None:
#     306     return t
#
# KeyboardInterrupt:

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# Predictions
y_pred_prob = model.predict(test_padded)
y_pred = (y_pred_prob > 0.5).astype(int)

# Confusion Matrix
cm = confusion_matrix(labels_test, y_pred)

# Calculate TP, FP, TN, FN
tp = cm[1, 1]
fp = cm[0, 1]
tn = cm[0, 0]
fn = cm[1, 0]

# Create a DataFrame for better visualization
confusion_df = pd.DataFrame(
    data=[[tn, fp], [fn, tp]],
    index=['Actual 0', 'Actual 1'],
    columns=['Predicted 0', 'Predicted 1']
)

# Plot the heatmap
sns.heatmap(confusion_df, annot=True, fmt='d', cmap='Blues', center=True)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# Classification Report
print(classification_report(labels_test, y_pred))
# Out:
# 195/195 [==============================] - 11s 38ms/step
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      1.00      3922
#          1.0       1.00      0.99      0.99      2312
#
#     accuracy                           1.00      6234
#    macro avg       1.00      0.99      0.99      6234
# weighted avg       1.00      1.00      1.00      6234

# %%
embedding_dim = 50  # Increased embedding dimension
model = Sequential([
    Embedding(input_dim=max_words, output_dim=embedding_dim, input_length=max_sequence_length),
    Bidirectional(LSTM(256, return_sequences=True)),  # Increased LSTM units
    Dropout(0.5),
    Bidirectional(LSTM(256)),
    Dense(128, activation='sigmoid'),  # Additional dense layer
    Dropout(0.5),
    Dense(1, activation='sigmoid')
])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 embedding_dim = 50  # Increased embedding dimension
# ----> 2 model = Sequential([
#       3     Embedding(input_dim=max_words, output_dim=embedding_dim, input_length=max_sequence_length),
#       4     Bidirectional(LSTM(256, return_sequences=True)),  # Increased LSTM units
#       5     Dropout(0.5),
#       6     Bidirectional(LSTM(256)),
#       7     Dense(128, activation='sigmoid'),  # Additional dense layer
#       8     Dropout(0.5),
#       9     Dense(1, activation='sigmoid')
#      10 ])
#
# NameError: name 'Sequential' is not defined

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])



early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

labels_train = train_data['Label']
labels_test = test_data['Label']

model.fit(train_padded, labels_train, epochs=10, validation_data=(test_padded, labels_test), callbacks=[early_stopping])


# Evaluate the model
test_loss, test_accuracy = model.evaluate(test_padded, labels_test)
print(f'Test Accuracy: {test_accuracy * 100:.2f}%')
# Out:
# Epoch 1/10
# 780/780 [==============================] - 83s 90ms/step - loss: 0.2116 - accuracy: 0.9253 - val_loss: 0.0804 - val_accuracy: 0.9920
# Epoch 2/10
# 780/780 [==============================] - 63s 81ms/step - loss: 0.0797 - accuracy: 0.9921 - val_loss: 0.0701 - val_accuracy: 0.9905
# Epoch 3/10
# 780/780 [==============================] - 64s 82ms/step - loss: 0.0601 - accuracy: 0.9950 - val_loss: 0.0643 - val_accuracy: 0.9933
# Epoch 4/10
# 780/780 [==============================] - 64s 83ms/step - loss: 4.3266 - accuracy: 0.7160 - val_loss: 9.5913 - val_accuracy: 0.3710
# Epoch 5/10
# 780/780 [==============================] - 70s 90ms/step - loss: 9.5219 - accuracy: 0.3756 - val_loss: 9.5913 - val_accuracy: 0.3710
# Epoch 6/10
# 780/780 [==============================] - 67s 85ms/step - loss: 9.5219 - accuracy: 0.3756 - val_loss: 9.5913 - val_accuracy: 0.3710
# 195/195 [==============================] - 6s 33ms/step - loss: 0.0643 - accuracy: 0.9933
# Test Accuracy: 99.33%

# %%
# Predictions
y_pred_prob = model.predict(test_padded)
y_pred = (y_pred_prob > 0.5).astype(int)

# Confusion Matrix
cm = confusion_matrix(labels_test, y_pred)

# Calculate TP, FP, TN, FN
tp = cm[1, 1]
fp = cm[0, 1]
tn = cm[0, 0]
fn = cm[1, 0]

# Create a DataFrame for better visualization
confusion_df = pd.DataFrame(
    data=[[tn, fp], [fn, tp]],
    index=['Actual 0', 'Actual 1'],
    columns=['Predicted 0', 'Predicted 1']
)

# Plot the heatmap
sns.heatmap(confusion_df, annot=True, fmt='d', cmap='Blues', center=True)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# Classification Report
print(classification_report(labels_test, y_pred))
# Out:
# 195/195 [==============================] - 10s 37ms/step
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99      3922
#          1.0       0.99      0.99      0.99      2312
#
#     accuracy                           0.99      6234
#    macro avg       0.99      0.99      0.99      6234
# weighted avg       0.99      0.99      0.99      6234
