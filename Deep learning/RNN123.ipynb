# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import StratifiedKFold
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout, Bidirectional
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import confusion_matrix, classification_report

# Load CSV file
df = pd.read_csv(r"C:\Users\abdel\Downloads\data set\SQLiV3.csv")

print(df.columns)
for i in range(0, 30953):
    if pd.isnull(df.iloc[i, 0]):
        df.iloc[i, 0] = df.iloc[i, 1]
    elif pd.isnull(df.iloc[i, 1]):
        df.iloc[i, 1] = df.iloc[i, 2]

print(df.isna().sum())
print(df.head())

# Data Cleaning
df['Label'] = df['Label'].astype(str)
df = df[~df['Label'].str.contains('[a-zA-Z]')]
df['Label'] = pd.to_numeric(df['Label'], errors='coerce', downcast='integer')
df['Label'] = df['Label'].astype('float32')
df = df.dropna(subset=['Sentence', 'Label'])

# Tokenization and Padding
max_words = 10000
max_sequence_length = 100
tokenizer = Tokenizer(num_words=max_words, oov_token="<OOV>")
tokenizer.fit_on_texts(df['Sentence'])
sequences = tokenizer.texts_to_sequences(df['Sentence'])
padded_sequences = pad_sequences(sequences, maxlen=max_sequence_length, padding='post', truncating='post')

# RNN Model
embedding_dim = 50  # Increased embedding dimension
model = Sequential([
    Embedding(input_dim=max_words, output_dim=embedding_dim, input_length=max_sequence_length),
    Bidirectional(LSTM(256, return_sequences=True)),  # Increased LSTM units
    Dropout(0.5),
    Bidirectional(LSTM(256)),
    Dense(128, activation='relu'),  # Additional dense layer
    Dropout(0.5),
    Dense(1, activation='sigmoid')
])
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# K-fold Cross-Validation
k_folds =10  
skf = StratifiedKFold(n_splits=k_folds, shuffle=True, random_state=42)

# Initialize variables to store metrics
all_tp, all_fp, all_tn, all_fn = 0, 0, 0, 0
overall_accuracy = 0.0  # Initialize overall accuracy variable

for fold, (train_index, test_index) in enumerate(skf.split(padded_sequences, df['Label'])):
    print(f"\nTraining Fold {fold + 1}")
    
    train_padded = padded_sequences[train_index]
    test_padded = padded_sequences[test_index]
    
    labels_train = df['Label'].iloc[train_index]
    labels_test = df['Label'].iloc[test_index]

    # Early stopping
    early_stopping = EarlyStopping(monitor='val_loss', patience=2, restore_best_weights=True)
    
    # Training
    model.fit(train_padded, labels_train, epochs=10, validation_data=(test_padded, labels_test), callbacks=[early_stopping])

    # Evaluate
    test_loss, test_accuracy = model.evaluate(test_padded, labels_test)
    overall_accuracy += test_accuracy  # Accumulate accuracy for each fold
    print(f'Test Accuracy (Fold {fold + 1}): {test_accuracy * 100:.2f}%')

    # Confusion Matrix and Metrics
    predictions = (model.predict(test_padded) > 0.5).astype("int32")
    cm = confusion_matrix(labels_test, predictions)

    tp, fp, fn, tn = cm.ravel()
    all_tp += tp
    all_fp += fp
    all_tn += tn
    all_fn += fn

# Calculate and print overall accuracy
overall_accuracy /= k_folds
print(f'\nOverall Accuracy Across all Folds: {overall_accuracy * 100:.2f}%')
# Out:
# Index(['Sentence', 'Label', 'Unnamed: 2', 'Unnamed: 3'], dtype='object')
# Sentence          2
# Label             2
# Unnamed: 2    30648
# Unnamed: 3    30945
# dtype: int64
#                                             Sentence Label Unnamed: 2  \
# 0                  " or pg_sleep  (  __TIME__  )  --     1        NaN
# 1  create user name identified by pass123 tempora...     1          1
# 2   AND 1  =  utl_inaddr.get_host_address   (    ...     1        NaN
# 3   select * from users where id  =  '1' or @ @1 ...     1        NaN
# 4   select * from users where id  =  1 or 1#"  ( ...     1        NaN
#
#    Unnamed: 3
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#
# Training Fold 1
# Epoch 1/10
# 869/869 [==============================] - 1263s 1s/step - loss: 0.0589 - accuracy: 0.9826 - val_loss: 0.0149 - val_accuracy: 0.9955
# Epoch 2/10
# 869/869 [==============================] - 1745s 2s/step - loss: 0.0197 - accuracy: 0.9958 - val_loss: 0.0188 - val_accuracy: 0.9932
# Epoch 3/10
# 869/869 [==============================] - 1703s 2s/step - loss: 0.0168 - accuracy: 0.9960 - val_loss: 0.0150 - val_accuracy: 0.9942
# 97/97 [==============================] - 26s 272ms/step - loss: 0.0149 - accuracy: 0.9955
# Test Accuracy (Fold 1): 99.55%
# 97/97 [==============================] - 25s 250ms/step
#
# Training Fold 2
# Epoch 1/10
# 869/869 [==============================] - 1379s 2s/step - loss: 0.0203 - accuracy: 0.9959 - val_loss: 0.0213 - val_accuracy: 0.9948
# Epoch 2/10
# 869/869 [==============================] - 1396s 2s/step - loss: 0.0127 - accuracy: 0.9968 - val_loss: 0.0227 - val_accuracy: 0.9948
# Epoch 3/10
# 869/869 [==============================] - 1379s 2s/step - loss: 0.0125 - accuracy: 0.9972 - val_loss: 0.0218 - val_accuracy: 0.9951
# 97/97 [==============================] - 24s 247ms/step - loss: 0.0213 - accuracy: 0.9948
# Test Accuracy (Fold 2): 99.48%
# 97/97 [==============================] - 25s 259ms/step
#
# Training Fold 3
# Epoch 1/10
# 869/869 [==============================] - 1292s 1s/step - loss: 0.0133 - accuracy: 0.9969 - val_loss: 0.0164 - val_accuracy: 0.9964
# Epoch 2/10
# 869/869 [==============================] - 995s 1s/step - loss: 0.0100 - accuracy: 0.9976 - val_loss: 0.0201 - val_accuracy: 0.9951
# Epoch 3/10
# 869/869 [==============================] - 990s 1s/step - loss: 0.0078 - accuracy: 0.9985 - val_loss: 0.0185 - val_accuracy: 0.9955
# 97/97 [==============================] - 24s 246ms/step - loss: 0.0164 - accuracy: 0.9964
# Test Accuracy (Fold 3): 99.64%
# 97/97 [==============================] - 24s 248ms/step
#
# Training Fold 4
# Epoch 1/10
# 869/869 [==============================] - 1007s 1s/step - loss: 0.0111 - accuracy: 0.9977 - val_loss: 0.0102 - val_accuracy: 0.9981
# Epoch 2/10
# 869/869 [==============================] - 1029s 1s/step - loss: 0.0083 - accuracy: 0.9983 - val_loss: 0.0113 - val_accuracy: 0.9974
# Epoch 3/10
# 869/869 [==============================] - 1273s 1s/step - loss: 0.0088 - accuracy: 0.9983 - val_loss: 0.0110 - val_accuracy: 0.9981
# 97/97 [==============================] - 24s 243ms/step - loss: 0.0102 - accuracy: 0.9981
# Test Accuracy (Fold 4): 99.81%
# 97/97 [==============================] - 23s 241ms/step
#
# Training Fold 5
# Epoch 1/10
# 869/869 [==============================] - 1338s 2s/step - loss: 0.0079 - accuracy: 0.9985 - val_loss: 0.0078 - val_accuracy: 0.9981
# Epoch 2/10
# 869/869 [==============================] - 1011s 1s/step - loss: 0.0090 - accuracy: 0.9982 - val_loss: 0.0087 - val_accuracy: 0.9981
# Epoch 3/10
# 869/869 [==============================] - 1550s 2s/step - loss: 0.0082 - accuracy: 0.9985 - val_loss: 0.0088 - val_accuracy: 0.9981
# 97/97 [==============================] - 36s 373ms/step - loss: 0.0078 - accuracy: 0.9981
# Test Accuracy (Fold 5): 99.81%
# 97/97 [==============================] - 36s 366ms/step
#
# Training Fold 6
# Epoch 1/10
# 869/869 [==============================] - 1521s 2s/step - loss: 0.0126 - accuracy: 0.9973 - val_loss: 0.0047 - val_accuracy: 0.9987
# Epoch 2/10
# 869/869 [==============================] - 1308s 2s/step - loss: 0.0099 - accuracy: 0.9983 - val_loss: 0.0042 - val_accuracy: 0.9994
# Epoch 3/10
# 869/869 [==============================] - 37741s 43s/step - loss: 0.0073 - accuracy: 0.9987 - val_loss: 0.0035 - val_accuracy: 0.9990
# Epoch 4/10
# 869/869 [==============================] - 1320s 2s/step - loss: 0.0072 - accuracy: 0.9986 - val_loss: 0.0041 - val_accuracy: 0.9990
# Epoch 5/10
# 869/869 [==============================] - 1134s 1s/step - loss: 0.0069 - accuracy: 0.9988 - val_loss: 0.0044 - val_accuracy: 0.9987
# 97/97 [==============================] - 24s 244ms/step - loss: 0.0035 - accuracy: 0.9990
# Test Accuracy (Fold 6): 99.90%
# 97/97 [==============================] - 23s 240ms/step
#
# Training Fold 7
# Epoch 1/10
# 869/869 [==============================] - 1472s 2s/step - loss: 0.0068 - accuracy: 0.9988 - val_loss: 0.0038 - val_accuracy: 0.9990
# Epoch 2/10
# 869/869 [==============================] - 2661s 3s/step - loss: 0.0079 - accuracy: 0.9987 - val_loss: 0.0204 - val_accuracy: 0.9974
# Epoch 3/10
# 869/869 [==============================] - 1345s 2s/step - loss: 0.0072 - accuracy: 0.9987 - val_loss: 0.0050 - val_accuracy: 0.9990
# 97/97 [==============================] - 34s 354ms/step - loss: 0.0038 - accuracy: 0.9990
# Test Accuracy (Fold 7): 99.90%
# 97/97 [==============================] - 31s 323ms/step
#
# Training Fold 8
# Epoch 1/10
# 869/869 [==============================] - 1295s 1s/step - loss: 0.0079 - accuracy: 0.9987 - val_loss: 2.5290e-04 - val_accuracy: 1.0000
# Epoch 2/10
# 869/869 [==============================] - 1049s 1s/step - loss: 0.0079 - accuracy: 0.9985 - val_loss: 0.0017 - val_accuracy: 0.9997
# Epoch 3/10
# 869/869 [==============================] - 1090s 1s/step - loss: 0.0086 - accuracy: 0.9987 - val_loss: 3.0252e-04 - val_accuracy: 1.0000
# 97/97 [==============================] - 26s 268ms/step - loss: 2.5290e-04 - accuracy: 1.0000
# Test Accuracy (Fold 8): 100.00%
# 97/97 [==============================] - 25s 254ms/step
#
# Training Fold 9
# Epoch 1/10
# 869/869 [==============================] - 1277s 1s/step - loss: 0.0112 - accuracy: 0.9978 - val_loss: 0.0036 - val_accuracy: 0.9994
# Epoch 2/10
# 869/869 [==============================] - 1360s 2s/step - loss: 0.0064 - accuracy: 0.9990 - val_loss: 0.0039 - val_accuracy: 0.9994
# Epoch 3/10
# 869/869 [==============================] - 1341s 2s/step - loss: 0.0061 - accuracy: 0.9989 - val_loss: 0.0031 - val_accuracy: 0.9994
# Epoch 4/10
# 869/869 [==============================] - 1320s 2s/step - loss: 0.0060 - accuracy: 0.9989 - val_loss: 0.0036 - val_accuracy: 0.9994
# Epoch 5/10
# 869/869 [==============================] - 1336s 2s/step - loss: 0.0061 - accuracy: 0.9990 - val_loss: 0.0035 - val_accuracy: 0.9994
# 97/97 [==============================] - 23s 241ms/step - loss: 0.0031 - accuracy: 0.9994
# Test Accuracy (Fold 9): 99.94%
# 97/97 [==============================] - 24s 251ms/step
#
# Training Fold 10
# Epoch 1/10
# 869/869 [==============================] - 1369s 2s/step - loss: 0.0062 - accuracy: 0.9989 - val_loss: 0.0082 - val_accuracy: 0.9987
# Epoch 2/10
# 869/869 [==============================] - 1418s 2s/step - loss: 0.0072 - accuracy: 0.9987 - val_loss: 0.0147 - val_accuracy: 0.9974
# Epoch 3/10
# 869/869 [==============================] - 1424s 2s/step - loss: 0.0059 - accuracy: 0.9989 - val_loss: 0.0114 - val_accuracy: 0.9987
# 97/97 [==============================] - 30s 309ms/step - loss: 0.0082 - accuracy: 0.9987
# Test Accuracy (Fold 10): 99.87%
# 97/97 [==============================] - 28s 284ms/step
#
# Overall Accuracy Across all Folds: 99.79%

# %%
average_tp = all_tp / k_folds
average_fp = all_fp / k_folds
average_tn = all_tn / k_folds
average_fn = all_fn / k_folds

average_cm = pd.DataFrame(
    data=[[average_tn, average_fp], [average_fn, average_tp]],
    index=['Actual 0', 'Actual 1'],
    columns=['Predicted 0', 'Predicted 1']
)


sns.heatmap(average_cm, annot=True, fmt='.2f', cmap='Blues', center=True)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Average Confusion Matrix')
plt.show()

# Print average classification report
average_classification_report = classification_report(df['Label'], (model.predict(padded_sequences) > 0.5).astype(int))
print(f'\nAverage Classification Report:\n{average_classification_report}')
print(f'\nZiad:{average_cm}')
# Out:
# 966/966 [==============================] - 322s 333ms/step
#
# Average Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     19517
#          1.0       1.00      1.00      1.00     11380
#
#     accuracy                           1.00     30897
#    macro avg       1.00      1.00      1.00     30897
# weighted avg       1.00      1.00      1.00     30897
#
#
# Ziad:          Predicted 0  Predicted 1
# Actual 0       1132.7          1.2
# Actual 1          5.3       1950.5

# %%
model.save(r"C:\Users\abdel\Downloads\grm\abdo.h5")
